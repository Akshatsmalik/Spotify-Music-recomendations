# %%
import pandas
data=pandas.read_pickle('recomendation1.pickle')
data.head(1)
# Out:
#                            id                                           name  \
# 39501  6catF1lDhNTjjGa2GxRQNN  You'll Never Walk Alone - Mono; 2002 Remaster
#
#        popularity  duration_ms  explicit                     artists  \
# 39501          56       160187         0  ['Gerry & The Pacemakers']
#
#                        id_artists release_date  danceability  energy  ...  \
# 39501  ['3UmBeGyNwr4iDWi1vTxWi8']   2008-02-11         0.484   0.265  ...
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 39501     1       0.0322         0.394               0.0     0.149    0.285
#
#          tempo  time_signature  release_year  clusters
# 39501  113.564               3          2008         3
#
# [1 rows x 22 columns]

# %%
data1=data['release_year'].describe()
data1
# Out:
# count    310973.000000
# mean       2006.101459
# std           9.086345
# min        1991.000000
# 25%        1998.000000
# 50%        2006.000000
# 75%        2014.000000
# max        2021.000000
# Name: release_year, dtype: float64

# %%
data1=data[data['release_year']>1990]['id'].sample(5).tolist()
data1
# Out:
# ['6fR8o71HjPhIsSIH2wOthY',
#  '49vX5tCphUExfBAcrZvoEK',
#  '3YdgxvbJckLf7FoFQXAEmh',
#  '2qQpFbqqkLOGySgNK8wBXt',
#  '1oZc2I489qeDLWNJm7D0ep']

# %%
id ='0Ia4MiaS1RT7Evdj3g9ar5'
def findid(id):
    try:
        index=data[data['id']==id].index[0]
        # return id
    except IndexError:
        return 'wrong id'
    
    
    cluster=data.loc[index,'clusters']
    clustersongs=data[data['clusters']==cluster].copy()
    clustervector=data[data['cluster']==cluster]['vector'].values
    targetvector=data.loc[index,'vector'].reshape(-1,1)

    return {clustersongs,cluster,clustervector,targetvector}

    similarity=cosine_similarity(targetvector,clustervector)[0]

    clustersongs['similarity']=similarity
    recommendation = clustersongs[clustersongs['id'] != id].sort_values(by='similarity', ascending=False)
    return recommendation['id'].head(5)

print(findid(id))
# Out:
# wrong id
